# %% [markdown]
# # **Survey Analysis**

# %%
# !pip install langchain_experimental
# !pip install langchain
# !pip install langchain-groq
# !pip install openai
import os
import pandas as pd
from langchain_experimental.agents import create_csv_agent # Import from the correct module
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain.llms import OpenAI
from langchain.chat_models import ChatOllama # Import ChatOllama from langchain.chat_models instead
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Create a dataframe panda from the csv file

# %%
# Read the CSV file, handling errors and specifying delimiter
df = pd.read_csv('data.csv', encoding='latin-1', on_bad_lines='skip', sep=';')

print(df.head())
# Out:
#    ID       heure_debut         heure_fin messagerie utilisation  \
# 0  14  2/17/25 14:12:50  2/17/25 14:17:49  anonymous         Oui
# 1  15  2/17/25 14:11:39  2/17/25 14:24:06  anonymous         Oui
# 2  16  2/17/25 14:15:44  2/17/25 14:27:10  anonymous         Oui
# 3  17  2/17/25 14:25:24  2/17/25 14:40:47  anonymous         Oui
# 4  18  2/17/25 14:42:08  2/17/25 14:42:25  anonymous         Non
#
#            entite  utilisation_frequence  \
# 0        Commerce                    3.0
# 1        Commerce                    3.0
# 2        Commerce                    5.0
# 3  Bid management                    5.0
# 4             NaN                    NaN
#
#                                               tache1  \
# 0  En tant qu'outil d'aide a la redaction de prop...
# 1  En tant qu'outil d'aide a la redaction de prop...
# 2  En tant qu'outil d'aide a la redaction d'offre...
# 3  En tant qu'outil d'aide a la redaction d'offre...
# ...

# %%
# Reading an Excel file
#excel_file_path = 'your_file.xlsx'
#df = pd.read_excel(excel_file_path, encoding='latin-1', on_bad_lines='skip', sep=';')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-ea5bfffe3509> in <cell line: 0>()
#       1 # Reading a CSV file
#       2 csv_file_path = 'data.csv'
# ----> 3 df_csv = pd.read_csv(csv_file_path)
#       4
#       5 # Reading an Excel file
#
# ...

# %%
# set your openai key here
os.environ["OPENAI_API_KEY"] = "sk-...."
agent = create_csv_agent(OpenAI(temperature=0), 'data.csv', verbose=True, pandas_kwargs={'encoding': 'latin-1', 'sep': ';'})
# Start our "interrogation"
agent.run("How many rows are in the dataframe?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5e57e9de621e> in <cell line: 0>()
#       1 # set your openai key here
#       2 os.environ["OPENAI_API_KEY"] = "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"
# ----> 3 agent = create_csv_agent(OpenAI(temperature=0), 'data.csv', verbose=True, pandas_kwargs={'encoding': 'latin-1', 'sep': ';'})
#       4 # Start our "interrogation"
#       5 agent.run("How many rows are in the dataframe?")
#
# /usr/local/lib/python3.11/dist-packages/langchain_experimental/agents/agent_toolkits/csv/base.py in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      64     else:
#      65         raise ValueError(f"Expected str, list, or file-like object, got {type(path)}")
# ...

# %%
# set your openai key here
os.environ["OPENAI_API_KEY"] = "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"
# Setting allow_dangerous_code=True to enable the agent
agent = create_csv_agent(OpenAI(temperature=0), 'data.csv', verbose=True, pandas_kwargs={'encoding': 'latin-1', 'sep': ';'}, allow_dangerous_code=True)
# Start our "interrogation"
agent.run("How many rows are in the dataframe?")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-25-8a7c18ac85f7> in <cell line: 0>()
#       4 agent = create_csv_agent(OpenAI(temperature=0), 'data.csv', verbose=True, pandas_kwargs={'encoding': 'latin-1', 'sep': ';'}, allow_dangerous_code=True)
#       5 # Start our "interrogation"
# ----> 6 agent.run("How many rows are in the dataframe?")
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
# ...

# %%
llm = OpenAI(temperature=0)

agent = create_pandas_dataframe_agent(llm, df, agent_type="openai-tools", verbose=True)
agent.invoke(
    {
        "input": "What's the suject of the survey?"
    }
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-46b27248de46> in <cell line: 0>()
#       1 llm = OpenAI(temperature=0)
#       2
# ----> 3 agent = create_pandas_dataframe_agent(llm, df, agent_type="openai-tools", verbose=True)
#       4 agent.invoke(
#       5     {
#
# /usr/local/lib/python3.11/dist-packages/langchain_experimental/agents/agent_toolkits/pandas/base.py in create_pandas_dataframe_agent(llm, df, agent_type, callback_manager, prefix, suffix, input_variables, verbose, return_intermediate_steps, max_iterations, max_execution_time, early_stopping_method, agent_executor_kwargs, include_df_in_prompt, number_of_head_rows, extra_tools, engine, allow_dangerous_code, **kwargs)
#     247     """
#     248     if not allow_dangerous_code:
# --> 249         raise ValueError(
# ...

# %%
llm = OpenAI(temperature=0)

# Set allow_dangerous_code=True when creating the agent
agent = create_pandas_dataframe_agent(llm, df, agent_type="openai-tools", verbose=True, allow_dangerous_code=True)
agent.invoke(
    {
        "input": "What's the suject of the survey?"
    }
)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-fbd51b0a571a> in <cell line: 0>()
#       3 # Set allow_dangerous_code=True when creating the agent
#       4 agent = create_pandas_dataframe_agent(llm, df, agent_type="openai-tools", verbose=True, allow_dangerous_code=True)
# ----> 5 agent.invoke(
#       6     {
#       7         "input": "What's the suject of the survey?"
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
# ...

# %%
llm = OpenAI(temperature=0)

# Change the agent_type to "zero-shot-react-description"
agent = create_pandas_dataframe_agent(llm, df, agent_type="zero-shot-react-description", verbose=True, allow_dangerous_code=True)
agent.invoke(
    {
        "input": "What's the size of the dataframe?"
    }
)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-18-6fc33d2019a6> in <cell line: 0>()
#       3 # Change the agent_type to "zero-shot-react-description"
#       4 agent = create_pandas_dataframe_agent(llm, df, agent_type="zero-shot-react-description", verbose=True, allow_dangerous_code=True)
# ----> 5 agent.invoke(
#       6     {
#       7         "input": "What's the size of the dataframe?"
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
# ...

# %%
# !pip install tenacity
from tenacity import retry, stop_after_attempt, wait_exponential

from IPython import get_ipython
from IPython.display import display
# %%

# %% [markdown]
# # **Survey Analysis**
# %%
# !pip install langchain_experimental
# !pip install langchain
# !pip install openai
import os
import pandas as pd
from langchain_experimental.agents import create_csv_agent # Import from the correct module
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain.llms import OpenAI

# %% [markdown]
# Create a dataframe panda from the csv file
# %%
# Read the CSV file, handling errors and specifying delimiter
df = pd.read_csv('data.csv', encoding='
# Out:
#   File "<ipython-input-19-9b5cf8fee6f3>", line 24
#     df = pd.read_csv('data.csv', encoding='
#                                           ^
# SyntaxError: unterminated string literal (detected at line 24)

# %%
from langchain.llms import HuggingFaceTextGenInference
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain

DB_FAISS_PATH = "vectorstore/db_faiss"
loader = CSVLoader(file_path="data.csv", encoding="utf-8", csv_args={'delimiter': ';'})
data = loader.load()

# Split the text into Chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# Download Sentence Transformers Embedding From Hugging Face
embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')

# COnverting the text Chunks into embeddings and saving the embeddings into FAISS Knowledge Base
docsearch = FAISS.from_documents(text_chunks, embeddings)

docsearch.save_local(DB_FAISS_PATH)

llm = HuggingFaceTextGenInference(
    inference_server_url="http://127.0.0.1:8080/",
    max_new_tokens=512,
    top_k=50,
    temperature=0.1,
    repetition_penalty=1.03,
)

qa = ConversationalRetrievalChain.from_llm(llm, retriever=docsearch.as_retriever())

exit = 0
while exit != 1:
    chat_history = []
    query = input(f"Input Prompt: ")
    if query == 'exit':
        print('Exiting')
        exit = 1
        break
    if query == '':
        continue
    result = qa({"question":query, "chat_history":chat_history})
    print("Response: ", result['answer'])

# %%
from langchain.llms import HuggingFaceTextGenInference
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain

DB_FAISS_PATH = "vectorstore/db_faiss"
# Change the encoding to 'latin-1' to match the actual file encoding
loader = CSVLoader(file_path="data.csv", encoding="latin-1", csv_args={'delimiter': ';'})
data = loader.load()

# Split the text into Chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# Download Sentence Transformers Embedding From Hugging Face
embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')

# COnverting the text Chunks into embeddings and saving the embeddings into FAISS Knowledge Base
docsearch = FAISS.from_documents(text_chunks, embeddings)

docsearch.save_local(DB_FAISS_PATH)

llm = HuggingFaceTextGenInference(
    inference_server_url="http://127.0.0.1:8080/",
    max_new_tokens=512,
    top_k=50,
    temperature=0.1,
    repetition_penalty=1.03,
)

qa = ConversationalRetrievalChain.from_llm(llm, retriever=docsearch.as_retriever())

exit = 0
while exit != 1:
    chat_history = []
    query = input(f"Input Prompt: ")
    if query == 'exit':
        print('Exiting')
        exit = 1
        break
    if query == '':
        continue
    result = qa({"question":query, "chat_history":chat_history})
    print("Response: ", result['answer'])
# Out:
# <ipython-input-22-c7bb5c3ce770>:18: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
llama3_8b = ChatOllama(model="llama3:instruct",
                   base_url = "http://10.179.0.20:5911", # Pour aller interroger l'Ollama à distance (via GPU) / Plus besoin de faire le choix des GPU en début de notebook !?
                   temperature=0.0) #local_llm
# Out:
# <ipython-input-4-16621648f656>:1: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   llama3_8b = ChatOllama(model="llama3:instruct",
